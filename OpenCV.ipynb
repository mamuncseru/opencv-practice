# %% [markdown]
# <a href="https://colab.research.google.com/github/mamuncseru/opencv-practice/blob/main/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('/content/rafsan.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread('wrong/path/doesnot/dlsfjlsjd.jpg')

# %%
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('/content/rafsan.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 99, 122, 148],
#         [ 99, 122, 148],
#         [ 99, 122, 148],
#         ...,
#         [ 87, 117, 142],
#         [ 87, 117, 142],
#         [ 87, 117, 142]],
#
#        [[ 99, 122, 148],
#         [ 99, 122, 148],
#         [ 99, 122, 148],
#         ...,
#         [ 87, 117, 142],
#         [ 87, 117, 142],
#         [ 87, 117, 142]],
#
#        [[ 99, 122, 148],
#         [ 99, 122, 148],
#         [ 99, 122, 148],
#         ...,
#         [ 87, 117, 142],
#         [ 87, 117, 142],
#         [ 87, 117, 142]],
#
#        ...,
#
#        [[ 21,  30,  44],
#         [ 21,  30,  44],
#         [ 21,  30,  44],
#         ...,
#         [ 68,  88, 145],
#         [ 68,  88, 145],
#         [ 68,  88, 145]],
#
#        [[ 21,  30,  44],
#         [ 21,  30,  44],
#         [ 21,  30,  44],
#         ...,
#         [ 65,  85, 142],
#         [ 65,  85, 142],
#         [ 65,  85, 142]],
#
#        [[ 21,  30,  44],
#         [ 21,  30,  44],
#         [ 21,  30,  44],
# ...

# %%
img.shape
# Out:
# (1980, 1472, 3)

# %%
plt.imshow(img)

# %%
# Matplotlib --> RED GREEN BLUE(RGB)
# OPENCV --> BLUE GREEN RED(BGR)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('/content/rafsan.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1980, 1472)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
new_img = cv2.resize(fix_img, (1000, 400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8
h_ratio = 0.2

# %%
new_img = cv2.resize(fix_img, (0, 0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img, -1)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
